# %% [markdown]
# # **MATLAB Onramp**
#
# # **1. Commands**
#
# Enter commands in MATLAB to perform calculations and create variables.
#  1. Entering Commands
#  2. Naming Variables
#  3. Saving and Loading Variables
#  4. Using Built-in Functions and Constants
#
# # **2. MATLAB Desktop and Editor**
#
# Write and save your own MATLAB programs.
#  1. MATLAB Desktop and Editor
#  2. The MATLAB Editor
#  3. Running Scripts
#
# # **3. Vectors and Matrices**
#
# Create MATLAB variables that contain multiple elements.
#  1. Manually Entering Arrays
#  2. Creating Evenly-Spaced Vectors
#  3. Array Creation Functions
#
# # **4. Indexing into and Modifying Arrays**
#
# Use indexing to extract and modify rows, columns, and elements of MATLAB arrays.
#  1. Indexing into Arrays
#  2. Extracting Multiple Elements
#  3. Changing Values in Arrays
#
# # **5. Array Calculations**
# Perform calculations on entire arrays at once.
# 1. Performing Array Operations on Vectors
#
# # **6. Calling Functions**
# Call functions to obtain multiple outputs.
#  1. Obtaining Multiple Outputs from Function Calls
#
# # **7. Obtaining Help**
# Use the MATLAB documentation to discover information about MATLAB features.
#  1. Obtaining Help
#
# # **8. Plotting Data**
# Visualize variables using MATLAB's plotting functions.
#  1. Plotting Vectors
#  2. Annotating Plots
#
# # **9. Problems Projects**
# Bring together concepts that you have learned with a project.
#  1. Project - Electricity Usage
#  2. Project - Audio Frequency
#
# # **10. Importing Data**
# Bring data from external files into MATLAB.
#  1. Import Tool
#  2. Importing Data as a Table
#
# # **11. Logical Arrays**
# Use logical expressions to help you to extract elements of interest from MATLAB arrays.
#  1. Logical Indexing
#
#
# # **12. Programming**
# Write programs that execute code based upon some condition.
#  1. Programming Constructs
#  2. Decision Branching
# For Loops
#
# # **13. Final Project**
# Bring together concepts that you have learned with a project.
#  1. Project - Stellar Motion
#  2. Project - Stellar Motion II
#
# # **14. Conclusion**

# %% [markdown]
# # **1. Commands**

# %% [markdown]
# ## **1.1 Entering Commands**

# %% [markdown]
# ### **Task 2**

# %%
 m=3*5

 # m = 15

# %% [markdown]
# ### **Task 3**

# %%
m=m+1

# m = 16

# %% [markdown]
# ### **Task 4**

# %%
y=m/2

# y = 8

# %% [markdown]
#  **TASK 5**
#
# `Enter k = 8 - 2; `
#
# with a semicolon at the end.
#
# The result won't appear in the command prompt, but you can see the value in the Workspace window.

# %%
k=8-2;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Task 6**

# %%
m=3*k

# m = 18

# %%
y = 8

# %%
y = m/2 

y = 9

# %% [markdown]
# ## **1.2 Naming Variables**

# %% [markdown]
# ### **TASK 1**
#
# Assign the value -2 to the variable A.

# %%
>> A = -2

A =  -2

# %% [markdown]
# ### **TASK 2**
#
# Calculate $\frac{a+A}{2}$
# . Assign the result to the variable avgAa

# %%
>> avgAa= (a+A)/2

avgAa =  3

# %% [markdown]
# ## **1.3 Saving and Loading Variables**

# %% [markdown]
# **TASK 1**
#
# Save the workspace variable to a file named **datafile.mat**

# %%
 Task 1 ✔
 
>> save datafile.mat

# %% [markdown]
# **TASK 2**
#
# Use clear to empty the workspace.

# %%
  Task 2 ✔
  
>> clear

# %% [markdown]
# **TASK 3**
#
# Load the variables from the file **datafile.mat**.

# %%
   Task 3 ✔
   
>> load datafile.mat

# %% [markdown]
# **TASK 4**
#
# Display the contents of the variable data.

# %%
data =

    3.0000    0.5300    4.0753       NaN
   18.0000    1.7800    6.6678    2.1328
   19.0000    0.8600    1.5177    3.6852
   20.0000    1.6000    3.6375    8.5389
   21.0000    3.0000    4.7243   10.1570
   23.0000    6.1100    9.0698    2.8739
   38.0000    2.5400    5.3002    4.4508

# %% [markdown]
# **TASK 5**
#
# Clear the command window using the clc command.

# %%
clc

# %% [markdown]
# ## **1.4 Using Built-in Functions and Constants**

# %% [markdown]
# **TASK 1**
#
# Create a variable called x with a value of π/2.

# %%
   Task 1 ✔
>> x= pi/2

 x =  1.5708

# %% [markdown]
#  **TASK 2**
#
# Use the sin function to calculate the **sine of x**.
#
# Assign the result to a variable named **y**.

# %%
 Task 2 ✔
>> y = sin(x)

y = 1

# %% [markdown]
# **TASK 3**
#
# Use the sqrt function to calculate the square root of -9.
#
# Assign the result to a variable named z.

# %%
  Task 3 ✔
>> z= sqrt(-9)

z = 0.0000 + 3.0000i

# %% [markdown]
# **Format function**

# %%
>> format long

>> z

z = 0.000000000000000 + 3.000000000000000i

# %%
>> format short 

>> z

z = 0.0000 + 3.0000i

# %% [markdown]
# # **2. MATLAB Desktop and Editor**

# %% [markdown]
# ## **2.1 The MATLAB Editor**

# %% [markdown]
# **TASK 1**
#
# Enter the command `r = 3` in the script.

# %%
r = 3

# %% [markdown]
# **TASK 2**
#
# Add the command `x = pi*r^2` to the script.

# %%
x = pi*r^2

x = 28.2743

# %% [markdown]
# ## **2.2 Running Scripts**
#
# Instructions are in the task pane to the left. Complete and submit each task one at a time.

# %% [markdown]
# **TASK 1**
#
# Run the script to populate the output pane.
#
# Then modify the command for **Task 1** so that **r has a value of 0.5**.

# %%
r = 0.5 

# Calculate circumference

y = 2*pi*r

y = 3.1416

# %% [markdown]
# # **3. Vectors and Matrices**

# %% [markdown]
# **What's an Array?**
#
# All MATLAB variables are arrays.
#  * This means that each numeric variable can contain multiple numbers.
#  * You can use arrays to store related data in one variable.
#
#
# Because you'll use arrays every time you program, it's important to get to know them and the terminology used to describe them

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3.1 Manually Entering Arrays**

# %% [markdown]
# ### **Creating Vectors**

# %% [markdown]
# **Task 1**
#
# Create a variable named **x with a value of 4**.

# %%
x = 4

# %% [markdown]
# **TASK 2**
#
# Create an array named x with two elements: 7 and 9

# %%
 x  = [ 7 9 ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TASK 3 : single column**
#
#  * Create an array named x with two elements, 7 and 9, in a **single column**.
#
#  * Try copying the previous command and changing the space between the numbers to a **semicolon (;)**.

# %%
x  = [7 ;9]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TASK 4: Row vector**
#
# Create a **row vector named x** that contains the values 3, 10, and 5 in that order.

# %%
 x  = [3  10  5]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TASK 5: matrix**
#
# Create a matrix named x with the values shown below.
#
#
# ```
# 5    6    7
# 8    9   10
#
# ```

# %%
x = [ 5 6 7 ;  8 9 10 ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TASK 6**
#
# * Create a row vector named `x` that contains **`sqrt(10)`** as its first element and **`pi^2 (π2)`** as its second element.

# %%
 x = [sqrt(10)  pi^2 ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Further Practice**

# %%
x = [7,1,8 ; 4, 5, 8 ; 10 4 2 ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3.2 Creating Evenly-Spaced Vectors**

# %% [markdown]
#  **TASK 1**
#
# Create a row vector named **x** that contains the values 1, 2, and 3, in that order.

# %%
x  = [1 2 3]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 2 - : operator**
#
# Create a row vector named x with the values 1, 2, 3, and 4, but this time using the `: operator`.

# %%
y = 1:4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TASK 3**
#
# Create a row vector named x that **starts at 1, ends at 5**, and each element is **separated by 0.5**.

# %%
x  = 1 : 0.5: 5

# %%
x  = 1 : 0.75: 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 3:2:13

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 4 : linspace function**:
#
# * **linspace(first,last,number_of_elements)**
#
# * Create a row vector named x that starts at 1, ends at 10, and contains 5 elements

# %%
x  = linspace(1,10,5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 5 : transpose operator (')**
#
# * Transpose x from a **row vector to a column vector** using the transpose operator.

# %%
x = linspace(1,10,5)

x = x'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TASK 6**
#
# * In a single command, **create a column vector named x** that starts at `5`, ends at `9` and has elements that are spaced by `2`.

# %%
x = (5:2:9)'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Logical Task**
#
# * If you wanted to create an **evenly-spaced vector** from `1 to 2π with 100 `elements, would you use `linspace` or `:`?

# %%
x  = linspace(1,2*pi,100)

# %% [markdown]
# ## **3.3 Array Creation Functions**

# %% [markdown]
# ### **TASK 1 : matrix of random numbers**
#
# * Create a variable named x that is a 5-by-5 matrix of random numbers.

# %%
x = rand(5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TASK 2**
#
# * Use rand to create an array that **`contains 5 rows and 1 column`**. Assign the result to a variable named x.

# %%
x = rand(5,1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 3 : zeros and ones functions**
#
# * Use the **`zeros function`** to create a matrix of all zeros that has `6 rows and 3 columns (6-by-3`). Assign the result to a variable named x.

# %%
x = zeros(6,3)

x = ones(2,3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Further Practice**
#
# * How do you get the **size of an existing matrix**?
#  *  You can use the size function  **`size(x)`**
#
# * You can also create a **matrix with the same size** as an existing matrix in one line of code.
#
#  * **`rand(size(x))`**

# %%
x = ones(2,3)

size(x)

y= rand(size(x))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **4. Indexing into and Modifying Arrays**

# %% [markdown]
# ## **4.1 Indexing into Arrays (Indexing into Arrays)**

# %%
load datafile
data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 1: extract values from an array**
#
# * Create a variable x that contains the value in the **`6th row and 3rd column`** of the variable data

# %%
x  = data(6,3)

# %%
x  = 9.0698

# %% [markdown]
# **TASK 2 : end keyword to obtain the value in the last element**
#
# * Use the end keyword to obtain the value in the last row and 3rd column of the variable data.
# *  Assign this value to a variable named x.

# %%
 x = data(end,3)

# %%
 x = 5.3002

# %% [markdown]
# **TASK 3 : arithmetic**
#
# * Create a scalar variable x that contains the value in the second to last **`(end-1) row `**and `3rd` column of `data`.

# %%
x = data(end-1,3)

# %%
x  = 9.0698

# %% [markdown]
# ## **4.2 Extracting Multiple Elements**

# %% [markdown]
# ### **TASK 1**
#
# * Create a variable named `density` that contains the second column of the matrix named `data`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
density = data(:,2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 2**
#
# * Create a variable `volumes` containing the **last two columns** of `data`.

# %%
volumes = data(:,end-1:end)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 3:  reference vector**
#
# * Using a single index value, create a variable named `p` containing the 6th element in the vector `density`.

# %%
p = density(6)

p  = 6.1100

# %% [markdown]
# ### **TASK 4 : range of index values**
#
# * Using a range of index values, create a vector named p containing the 2nd through 5th elements of density.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p= density(2:5)

# %% [markdown]
# ## **4.3 Changing Values in Arrays**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 1**
#
# * Create a vector named `v2` containing the last column of `data`.

# %%
v2= data(:,end)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 2**
#
# * Change the first element in **`v2`** from **`NaN`**

# %%
v2(1) = 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 3: Change the value of the element in matrix**
#
# * Change the value of the element in the first row and last column of data to 0.5.

# %%
data(1,end)= 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 3**
#
# * Try changing the first column of data to the second column of data

# %%
data(1)=data(2)

# %% [markdown]
# # **5. Array Calculations**

# %% [markdown]
# ## **5.1 Performing Array Operations on Vectors**

# %%
load datafile
density = data(:,2);
v1 = data(:,3);
v2 = data(:,4);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 1: Add 1 to each element**
#
# * Add 1 to each element of **`v1`** and store the result in a variable named **`r`**.

# %%
r = v1+ 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 2: Sum of vectors**
#
# * Create a vector **`vs`** that is the **sum of the vectors** **`v1`** and **`v2`**.

# %%
vs = v1 + v2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 3: Arithmatic**
#
# * Create a variable **`va`** that contains the value **`vs`** divided by 2 (the average volume).

# %%
va = vs/2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 4 :maximum of the vector**
#
# * Create a variable **`vm`** containing the maximum of the **`va`** vector.

# %%
vm = max(va)

# %%
vm = 7.4407

# %% [markdown]
# ### **TASK 5**
#
# * Using the round function, create a variable named **`vr`** which contains the rounded average volumes, **`va`**.

# %%
vr = round(va)

xSqrt = sqrt(vr)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 6 : Matrix multiplication**
#
# * Create a variable named **`mass`** containing the elementwise product of **`density`** and **`va`**.

# %% [markdown]
# https://fr.mathworks.com/help/matlab/ref/mtimes.html

# %%
mass = density .* va

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **: size of matrix**

# %%
size(va)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **6. Calling Functions**

# %% [markdown]
# ## **6.1 Obtaining Multiple Outputs from Function Calls**

# %%
load datafile
data
v1 = data(:,3);
v2 = data(:,4);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 1**
#
# * Create a variable named **`dsize`** containing the size of the **`data`** variable.

# %%
dsize = size(data)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 2 : Create the variables, contain the number of rows and columns of variable**
#
# * Create the variables **`dr`** and **`dc`** which respectively contain the number of **`rows`** and **`columns`** of the variable **`data`**.

# %%
# [xrow,xcol] = size(x)

 [dr, dc] = size(data)

# %% [markdown]
# ```
# dr = 7
# dc = 4
# ```

# %% [markdown]
# ### **TASK 3: maximum value of vector and the corresponding index value**
#
# * Create the variables **`vMax`** and **`ivMax`** containing the **maximum value** of the **`v2`** vector and the **corresponding index value** respectively.

# %%
# [xMax,idx] = max(x)   
#  [ maximum_value, index_value ] = max(x)

[vMax,ivMax] = max(v2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Further Practice**
# * Try getting the index value of the minimum value in **`v2`**. Use this index to extract from **`density`**.

# %%
density = data(:,2)

#  you can use a tilde (~) to ignore specific outputs

[~,ivMax] = max(v2)

densityMax = density(ivMax)

[~,ivMmin] = min(v2)

densityMin = density(ivMmin)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **7. documentation for randi**
#
# * Use the documentation for randi to help complete the task below.
#
# * https://fr.mathworks.com/help/matlab/ref/randi.html

# %% [markdown]
# ## **TASK 1**
#
# * Create a matrix named **`x`**
#  * that Contains random integers in the range from 1 to 20
#  * Has 5 rows
#  * Has 7 columns

# %%
x = randi(20,5,7)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = randi(10,15)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **8. Plotting Data**

# %% [markdown]
# ## **8.1 Plotting Vectors**

# %%
load datafile
sample = data(:,1);
density = data(:,2);
v1 = data(:,3);
v2 = data(:,4);
mass1 = density.*v1;
mass2 = density.*v2;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 1: plot**
#
# * **Two vectors of the same length can be plotted against each other using the `plot` function**.
#
# * Create a **`plot`** with **`sample`** on the **`x-axis`** and **`mass1`** on the **`y-axis.`**

# %%
# plot(x,y)

plot(sample,mass1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Imrove version 

plot(sample,mass1)

xlim([0.0 40.0])
ylim([0.0 60.0])

# %% [markdown]
# ### **TASK 2**
#
#
#
# * Plot **`mass2`** (y-axis) against **`sample`** (x-axis). Use red **`(r)`** star **`(*)`** markers and no line in your plot.

# %%
# plot(x,y,"r--o")

plot(sample,mass2,"r*")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * The command above plots a red **`(r)`** dashed **`(--)`** line with a circle  **`(o)`** as a marker.

# %% [markdown]
# ### **TASK 3: hold on**
#
# * Enter the **`hold on`**  command.
#
# * Then plot **mass1 (y-axis)** against **`sample`** (x-axis) with **black `(k)`** **square `(s)`** markers and no line.
# * https://fr.mathworks.com/help/matlab/ref/matlab.graphics.chart.primitive.line-properties.html

# %%
# plot(x1,y1)
# hold on
# plot(x2,y2)

plot(sample,mass2,"r*")
hold on
plot(sample,mass1,"ks")

xlim([0.0 40.0])
ylim([0.0 60.0])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * While the hold state is on, plots will continue to go on the same axes.
#
# * To return to the default plot behavior, where each plot gets its own axes, enter **`hold off.`**

# %%
hold off

# %% [markdown]
# ### **TASK 4: Plot a single vector**
#
# * Plot the vector **`v1`** using the command below.
#
#
# * When you plot a single vector by itself, MATLAB uses the **vector values** as the **y-axis data** and **sets the x-axis data to range from 1 to n** (the number of elements in the vector).

# %%
plot(v1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 5: Plot function accepts additional inputs**
#
# * The plot function accepts optional additional inputs consisting of a property name and an associated value.
#
# * Plot **`v1`** with a line width of 3.

# %%
 # plot(y,"LineWidth",5)

 plot(v1,"LineWidth",3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 6**
#
# * Plot **`v1`** (y-axis) against **`sample`** (x-axis) with red **`(r)`** circle **`(o)`** markers and a solid line **`(-)`**.
#
# * Use a line width of **`4`**.

# %%
# plot(x,y,"ro-","LineWidth",5)

plot(sample,v1,"ro-","LineWidth",3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 7 : MATLAB Plot Gallery**
#
# * https://fr.mathworks.com/products/matlab/plot-gallery.html

# %% [markdown]
# * Each plot has different customization options.
#
# * Try creating a histogram of density with the **`histogram`** function. Set the "**`FaceColor`**" to **`yellow`** (**`"y"`**).

# %%
figure

h1 = histogram(density,"FaceColor","y");

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **8.2. Annotating Plots**

# %%
load datafile
sample = data(:,1);
density = data(:,2);
v1 = data(:,3);
v2 = data(:,4);
mass1 = density.*v1;
mass2 = density.*v2;

# %%
# This code creates the plot from the last activity.

plot(sample,mass1,"ks")
hold on

plot(sample,mass2,"r*")
hold off

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 1:Add the title to plot**
#
# * Add the title "**`Sample Mass`**" to the existing plot.

# %%
# title("Plot Title")

 title("Sample Mass")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 2: Labels**
#
# * Use the **`ylabel`** function to add the label **`"Mass (g)"`**.

# %%
# title("Plot Title")
title("Sample Mass")

ylabel ("Mass (g)")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 3: Add a legend to your plot**
#
# * You can add a legend to your plot using the legend function.
#
# * Create a legend with the labels **`"Exp A"`** and **`"Exp B"`**, in that order.

# %%
# legend("a","b","c")

legend("Exp A","Exp B")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 4: Concatenating a string with a variable**
#
# * You can use a variable's value in plot annotations by concatenating a string with a variable:

# %%
data(3,:)

bar(data(3,:))

title("Sample " + sample(3) + " Data")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **9.1 Project - Electricity Usage**

# %% [markdown]
# ## **Task 1**

# %%
load electricity

usage

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Task 2**

# %%
usage(2,3)= 2.74

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Task 3**

# %%
res = usage(:,1)

comm = usage(:,2)

ind = usage(:,3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Task 4**

# %%
yrs = (1991:2013)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Task 5**

# %%
plot(yrs,res,"b--")
hold on
plot(yrs,comm,"k:*")
plot(yrs,ind,"m-.")

# %% [markdown]
# ## **Task 6**

# %%
title("July Electricity Usage")

legend( "res", "comm", "ind")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **9.2 Project 2: Audio Frequency**
#
# * Audio signals are usually comprised of many different frequencies.
# * For example, in music, the note 'middle C' has a fundamental frequency of 261.6 Hz, and most music consists of several notes (or frequencies) being played at the same time.
#
# * In this project, you will analyze the frequency content of an organ playing the C chord.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Task 1**

# %%
load Cchord

# numel function to return the number of elements in an array.

y   #  signal from recording
fs  #  sampling frequency

n = numel(y)  # number of elements 

t = 0:n-1   # evenly-spaced vector

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **TASK 2**
#
# * Divide **`t`** by **`fs`**. Assign the output to the same variable **`t`**. Then plot **`y`** against **`t`**.

# %% [markdown]
# * **`t`** now has the correct number of points, but it needs to represent the times when the audio signal was sampled.
#
# *  You can use the sampling frequency **`fs`** to convert the vector to time (in seconds).

# %%
t = t/fs

plot(t,y)   #  Then plot y against t = > (x,y)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **TASK 3:  discrete Fourier transform**
#
# * Create a variable named **`yfft`** that contains the **absolute value of the discrete Fourier transform** of **`y`**.

# %% [markdown]
# * A Fourier transform will return information about the frequency content of the signal. The location of the dominant frequencies will show what notes are contained in the chord.
#
# * You can use the **`fft`** function to compute the discrete Fourier transform of a vector.

# %%
yfft = abs(fft(y))

# %% [markdown]
# ## **TASK 4**
#
# * Create an evenly-spaced vector **`f`** that **`starts at 0, ends at n-1`**, and has elements that are spaced by 1

# %%
f = 0:n-1

# %% [markdown]
# ## **TASK 5**
#
# * Multiply **`f with fs/n`**. Assign the output to the same variable **`f`**.
#
# * Plot **`yfft`** against **`f`** using the **`x-limits 0 and 1000.`**

# %% [markdown]
# * The vector **`f`** now contains **`
# `**.
#
# * To convert these points to frequencies, you can multiply the entire vector by the **`sampling frequency (fs)`** and divide it by the number of **`points (n)`**.

# %%
f= f*(fs/n) 

plot(f,yfft) 
xlim([0 1000])
# xlim([xmin xmax])

ylim([0 2500])

# %%
load Cchord

y   # signal from recording
fs  #  sampling frequency

n = numel(y)  # number of elements 

t = 0:n-1   # evenly-spaced vector 

t = t/fs

yfft = abs(fft(y))

f = 0:n-1

f= f*(fs/n) 

plot(f,yfft)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **10. Importing Data as a Table**

# %%
#  Task 1

load datafile
elements

d = elements.Density

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Task 2 : Add mass 

elements.Mass = elements.Density .* elements.Volume1

elements = sortrows(elements,'Density');
elements = sortrows(elements,'Mass')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Task 3

top3 = elements(1:3,:)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **11. Logical ArraysLogical Indexing**
#
# * https://fr.mathworks.com/help/matlab/matlab_prog/array-comparison-with-relational-operators.html

# %%
load datafile
sample = data(:,1);
v1 = data(:,3);
v1

# %% [markdown]
# `[5 10 15] > 12`
#
#
# ```
# ans =
#     0    0    1
# ```

# %%
# Task 1
test = pi<4

# Task 2
test = v1 < 4  # vector elements that are less than 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Task 3
v =  v1(v1 < 4) #  containing all the elements of v1 that are less than four.

# Task 4
# v = sample(v1 > 6)
s = sample(v1 < 4) #  contains elements in sample to where v1 is less than 4

# Task 5
# x(x==999) = 1
v1(v1 < 4) = 0  #  any value less than 4 is replaced with value 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * To find values less than 4 and greater than 2, use **`&`**:
#
#  **`x = v1(v1<4 & v1>2)`**
#
# * To find values greater than 6 or less than 2, use **`|`**:
#
#  **`x = v1(v1>6 | v1<2)`**

# %%
# Further Practice
x = v1(v1<4 & v1>2)

x = v1(v1>6 | v1<2)

# %% [markdown]
# Use == to check for equality.
#
#
# ```
# if x == 0.5
#     y = 3
# end
# ```

# %% [markdown]
# # **12. Programming**

# %% [markdown]
# ## **12.1. Decision Branching**

# %% [markdown]
# * The body of an **`if`** block is only executed if the condition is true.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Use **`== to check for equality.`**
#
#
# ```
# if x == 0.5
#     y = 3
# end
# ```

# %% [markdown]
# ### **TASK 1**
#
# * Modify the script so that the plotting code on lines 4-7 are executed only when **`doPlot`** is **`1`**.

# %%
 # This code creates a random number to test the if statement.

doPlot = randi([0 1])

# This code loads the data.
load datafile
density = data(:,1);
density

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Solution 

if doPlot == 1
    plot(density)
    title("Sample Densities")
    xticklabels(element)
    ylabel("Density (g/cm^3)")
end

# result none

# %% [markdown]
# ### **TASK 2**
#
# * Modify the script so that when the **`if`** condition is not satisfied, the following line of code is executed:

# %%
disp("The density of " + element ...
    + " is " + density)

# %%
x = rand
if x > 0.5
    y = 3
else
    y = 4
end

# %%
if doPlot == 1
    plot(density)
    title("Sample Densities")
    xticklabels(element)
    ylabel("Density (g/cm^3)")
else 
    disp("The density of " + elet ...
    + " is " + density)
end

# %%
# " if doplot = 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# " if doplot = 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **12.2. For Loops**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 1**
#
# * Wrap the code in the second section of the live script (lines 4-7) in a loop so that the **code executes 7 times**.
#
# * Name your loop counter **`idx`**. For the first execution of the loop, **`idx`** should have a value of **`1`**, and it should increase by **`1`** each consecutive iteration.

# %%
#  This code loads the data
load datafile
density = data(:,1);

# %%
for idx = 1:7
    hold on
    plot(idx,density(idx),"*")
    hold off
    pause(0.2)
end

# %%
# stops the loop for 0.2 seconds so that the plot will update. 

pause(0.2)

# %%
# If you want to loop over a vector of unknown length

for idx = 1:length(density)
    hold on
    plot(idx,density(idx),"*")
    hold off
    pause(0.2)
end

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **13. Final Project**
#
# ## **13.1 Project - Stellar Motion**
#
# The spectra data was collected at evenly-spaced wavelengths, and you know the starting wavelength ($λ_{start}$), the spacing ($λ_{delta}$), and the number of observations

# %% [markdown]
# ### **TASK 1**
# * Create a variable named `lambdaEnd` ($λ_end$) that contains the value of the last wavelength in the recorded spectrum.
#
# * You can calculate `lambdaEnd` with the equation $λ_{start}+(nObs−1)λ_{delta}$
#
# * Use `lambdaEnd` to make a vector named lambda (λ) containing the wavelengths in the spectrum, from $λ_{start}$ to $λ_{end}$, in steps of $λ_{delta}$
#
# * Transpose `lambda` into a column vector so it can be plotted in Task 3.

# %%
lambdaEnd= lambdaStart + (nObs-1)*lambdaDelta

lambda = (lambdaStart : lambdaDelta : lambdaEnd)'

# %% [markdown]
# Remember that the colon `(:)` operator creates row vectors with a fixed stepsize.
#
# *  Use the transpose operator `(')` to turn a row into a column.

# %% [markdown]
# ### **Task 2**
#
# * Each column of spectra is the spectrum of a different star. The sixth column is the spectrum of star HD 94028.
#
# * Extract the sixth column of spectra to a vector named **`s`**.

# %%
s= spectra(:,6)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 3**
#
# * Use the **`loglog`** function in the same way as the plot function to obtain log scales for both axes.
#
# * Plot the spectra **`(s)`** as a function of wavelength (**`lambda`**), using log scales on both axes.
#
# *  Use point markers **`(.)`** and a solid line **`(-)`** connecting the points.

# %%
# loglog(x,y,"*--")

loglog(lambda,s,".-")
xlabel("Wavelength")
ylabel("Intensity")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 4**
#
# * Create two variables, **`sHa`** and **`idx`** that contain the minimum value of **`s`** and the index where the minimum value occurred.
#
# * Use **`idx`** to index into **`lambda`** to find the wavelength of the **Hydrogen-alpha** line.
#
# * Store the result as lambdaHa **($λ_{Ha}$)**.

# %%
#  [xMax,idx] = min(x) 

[ sHa,idx ] = min(s)   # minimum value of s and the index

lambdaHa = lambda(idx) # wavelength of the Hydrogen-alpha line

# %% [markdown]
# ```
#  sHa  =  9.8010e-14
#  idx  =  191
#  lambdaHa = 656.6200
#
# ```

# %% [markdown]
# ### **TASK 5**
#
# * Add a point to the existing graph by plotting
# *  x = **`lambdaHa`**, y = **`sHa`** as a red square ("`rs`") with a marker size (**"`MarkerSize`"**) of **`8`**

# %%
loglog(lambda,s,".-")
xlabel("Wavelength")
ylabel("Intensity")
hold on

plot(lambdaHa,sHa,"rs","MarkerSize",8)
hold off

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * If you zoom in on the plot, you can see that the wavelength of the **Hydrogen-alpha line of HD 94028 is 656.62 nm**,
#  *  which is slightly longer than the laboratory value of **656.28 nm**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Using the Hydrogen-alpha wavelength of the star, you can calculate the redshift factor (the speed of the star relative to the earth) using the formula $z=(λ_{Ha}/656.28)−1$.
#
# *  You can then calculate the speed by multiplying the redshift factor by the speed of light (299792.458 $km/s$).

# %% [markdown]
# ### **TASK 6**
#
# * Calculate the **redshift factor** and the speed (in $km/s$) at which the star is moving away from the earth.
#
# * Assign the redshift factor to a variable called **z** and the speed to a variable called **`speed`**.

# %%
z= (lambdaHa/656.28-1 )

# z = 5.1807e-04

speed= z*299792.458

# speed = 155.313

# %% [markdown]
# ## **13.2. Stellar Motion II**
#
# * In the previous project, you determined if one star's spectrum was redshifted or blueshifted, and calculated the star’s speed relative to the Earth.
#
# * In this project, you will calculate all the stars' speed at once. Then you'll create the plot below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
load starData

# %% [markdown]
# ### **Task 1**

# %%
# [sHa,idx] = min(spectra(:,2));

[sHa,idx] = min(spectra); % calculate the speed of all the stars.
lambdaHa = lambda(idx);
z = lambdaHa/656.28 - 1;
speed = z*299792.458

# %% [markdown]
# ### **TASK 2: for loop**

# %%
for v = 1:7            # for loop index progress through all col of spectra (1 to 7)

    s = spectra(:,v)  # extract the vth column of spectra
end

# %% [markdown]
# ### **TASK 3: if cond**

# %%
for v = 1:7
    s = spectra(:,v)
    
    if speed(v) <= 0    # if loop and cond 
        loglog(lambda,s,"--")
        xlabel("Wavelength")
        ylabel("Intensity")
    end

    hold on

end

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 4: if-else**

# %%
for v = 1:7   #  plot with seven lines exist?
    s = spectra(:,v)

    if speed(v) <= 0  
        loglog(lambda,s,"--") 
    else
        loglog(lambda,s,LineWidth=3)
    end
    hold on
end

hold off

# %% [markdown]
# ### **TASK 5: Add legend to the plot using array starnames**

# %%
legend(starnames)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 6**
#
# * Create a variable **`movaway`** that contains the elements in **`starnames`** corresponding to where **`speed`** is greater than **`0`**.

# %%
# Recall that you can use logical indexing to find elements that match a condition.

c = b(a < 6)

# %%
movaway= starnames (speed > 0)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **TASK 7**

# %%
loglog(lambda,spectra)
legend(starnames)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **14. Summary**

# %% [markdown]
# ## **1. Array types**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **2. Evenly-spaced vectors**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3. Creating matrices**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **4. Indexing**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **5. Array operations**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **6. Multiple outputs**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **7. Plotting**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **8. Logicals**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **9. Programming**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
